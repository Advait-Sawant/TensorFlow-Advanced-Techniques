# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 941us/sample - loss: 253.8551 - y1_output_loss: 113.1685 - y2_output_loss: 138.4542 - y1_output_root_mean_squared_error: 10.6863 - y2_output_root_mean_squared_error: 11.8177 - val_loss: 39.6492 - val_y1_output_loss: 16.3514 - val_y2_output_loss: 21.9894 - val_y1_output_root_mean_squared_error: 4.1133 - val_y2_output_root_mean_squared_error: 4.7676
# Epoch 2/500
# 614/614 [==============================] - 0s 142us/sample - loss: 31.4429 - y1_output_loss: 13.2387 - y2_output_loss: 18.0168 - y1_output_root_mean_squared_error: 3.6510 - y2_output_root_mean_squared_error: 4.2560 - val_loss: 31.7640 - val_y1_output_loss: 12.4998 - val_y2_output_loss: 18.3822 - val_y1_output_root_mean_squared_error: 3.5903 - val_y2_output_root_mean_squared_error: 4.3444
# Epoch 3/500
# 614/614 [==============================] - 0s 134us/sample - loss: 29.0977 - y1_output_loss: 11.2837 - y2_output_loss: 17.9475 - y1_output_root_mean_squared_error: 3.3307 - y2_output_root_mean_squared_error: 4.2431 - val_loss: 24.6596 - val_y1_output_loss: 10.3861 - val_y2_output_loss: 14.0025 - val_y1_output_root_mean_squared_error: 3.2322 - val_y2_output_root_mean_squared_error: 3.7700
# Epoch 4/500
# 614/614 [==============================] - 0s 130us/sample - loss: 24.8414 - y1_output_loss: 9.6841 - y2_output_loss: 15.0152 - y1_output_root_mean_squared_error: 3.1149 - y2_output_root_mean_squared_error: 3.8908 - val_loss: 32.5293 - val_y1_output_loss: 13.1828 - val_y2_output_loss: 18.5008 - val_y1_output_root_mean_squared_error: 3.6795 - val_y2_output_root_mean_squared_error: 4.3578
# Epoch 5/500
# 614/614 [==============================] - 0s 131us/sample - loss: 23.2748 - y1_output_loss: 9.4201 - y2_output_loss: 13.6916 - y1_output_root_mean_squared_error: 3.0814 - y2_output_root_mean_squared_error: 3.7121 - val_loss: 24.4520 - val_y1_output_loss: 9.7433 - val_y2_output_loss: 14.2843 - val_y1_output_root_mean_squared_error: 3.1476 - val_y2_output_root_mean_squared_error: 3.8138
# Epoch 6/500
# 614/614 [==============================] - 0s 138us/sample - loss: 27.0176 - y1_output_loss: 9.5225 - y2_output_loss: 17.5824 - y1_output_root_mean_squared_error: 3.0812 - y2_output_root_mean_squared_error: 4.1861 - val_loss: 50.9080 - val_y1_output_loss: 13.1544 - val_y2_output_loss: 37.7197 - val_y1_output_root_mean_squared_error: 3.6034 - val_y2_output_root_mean_squared_error: 6.1582
# Epoch 7/500
# 614/614 [==============================] - 0s 139us/sample - loss: 22.6134 - y1_output_loss: 8.8816 - y2_output_loss: 14.0142 - y1_output_root_mean_squared_error: 2.9587 - y2_output_root_mean_squared_error: 3.7228 - val_loss: 69.3325 - val_y1_output_loss: 18.8929 - val_y2_output_loss: 50.2014 - val_y1_output_root_mean_squared_error: 4.3289 - val_y2_output_root_mean_squared_error: 7.1129
# Epoch 8/500
# 614/614 [==============================] - 0s 133us/sample - loss: 24.7702 - y1_output_loss: 8.9836 - y2_output_loss: 15.5885 - y1_output_root_mean_squared_error: 3.0090 - y2_output_root_mean_squared_error: 3.9643 - val_loss: 18.1816 - val_y1_output_loss: 7.7381 - val_y2_output_loss: 10.5781 - val_y1_output_root_mean_squared_error: 2.7649 - val_y2_output_root_mean_squared_error: 3.2460
# Epoch 9/500
# 614/614 [==============================] - 0s 133us/sample - loss: 20.0495 - y1_output_loss: 8.4027 - y2_output_loss: 12.1568 - y1_output_root_mean_squared_error: 2.8578 - y2_output_root_mean_squared_error: 3.4471 - val_loss: 21.8966 - val_y1_output_loss: 9.2038 - val_y2_output_loss: 12.3663 - val_y1_output_root_mean_squared_error: 3.0537 - val_y2_output_root_mean_squared_error: 3.5456
# Epoch 10/500
# 614/614 [==============================] - 0s 130us/sample - loss: 19.0082 - y1_output_loss: 7.8030 - y2_output_loss: 11.1994 - y1_output_root_mean_squared_error: 2.7972 - y2_output_root_mean_squared_error: 3.3442 - val_loss: 18.4127 - val_y1_output_loss: 7.7644 - val_y2_output_loss: 10.4414 - val_y1_output_root_mean_squared_error: 2.7879 - val_y2_output_root_mean_squared_error: 3.2619
# Epoch 11/500
# 614/614 [==============================] - 0s 134us/sample - loss: 19.7768 - y1_output_loss: 8.0936 - y2_output_loss: 11.7944 - y1_output_root_mean_squared_error: 2.8450 - y2_output_root_mean_squared_error: 3.4180 - val_loss: 48.2768 - val_y1_output_loss: 10.7670 - val_y2_output_loss: 36.2298 - val_y1_output_root_mean_squared_error: 3.3204 - val_y2_output_root_mean_squared_error: 6.1034
# Epoch 12/500
# 614/614 [==============================] - 0s 128us/sample - loss: 19.0182 - y1_output_loss: 7.7693 - y2_output_loss: 11.3892 - y1_output_root_mean_squared_error: 2.7845 - y2_output_root_mean_squared_error: 3.3563 - val_loss: 31.1555 - val_y1_output_loss: 9.8423 - val_y2_output_loss: 20.4774 - val_y1_output_root_mean_squared_error: 3.1682 - val_y2_output_root_mean_squared_error: 4.5955
# Epoch 13/500
# 614/614 [==============================] - 0s 128us/sample - loss: 19.9335 - y1_output_loss: 7.7436 - y2_output_loss: 12.1356 - y1_output_root_mean_squared_error: 2.7923 - y2_output_root_mean_squared_error: 3.4838 - val_loss: 17.5132 - val_y1_output_loss: 7.1273 - val_y2_output_loss: 10.1933 - val_y1_output_root_mean_squared_error: 2.6738 - val_y2_output_root_mean_squared_error: 3.2193
# Epoch 14/500
# 614/614 [==============================] - 0s 129us/sample - loss: 21.6199 - y1_output_loss: 8.4183 - y2_output_loss: 13.5231 - y1_output_root_mean_squared_error: 2.8724 - y2_output_root_mean_squared_error: 3.6564 - val_loss: 53.0092 - val_y1_output_loss: 13.4289 - val_y2_output_loss: 39.9989 - val_y1_output_root_mean_squared_error: 3.6157 - val_y2_output_root_mean_squared_error: 6.3195
# Epoch 15/500
# 614/614 [==============================] - 0s 129us/sample - loss: 18.9007 - y1_output_loss: 7.6432 - y2_output_loss: 11.1161 - y1_output_root_mean_squared_error: 2.7731 - y2_output_root_mean_squared_error: 3.3482 - val_loss: 16.3647 - val_y1_output_loss: 6.8732 - val_y2_output_loss: 9.5018 - val_y1_output_root_mean_squared_error: 2.6061 - val_y2_output_root_mean_squared_error: 3.0940
# Epoch 16/500
# 614/614 [==============================] - 0s 129us/sample - loss: 20.4283 - y1_output_loss: 7.9895 - y2_output_loss: 12.4714 - y1_output_root_mean_squared_error: 2.8347 - y2_output_root_mean_squared_error: 3.5204 - val_loss: 32.8887 - val_y1_output_loss: 9.8929 - val_y2_output_loss: 22.7074 - val_y1_output_root_mean_squared_error: 3.1475 - val_y2_output_root_mean_squared_error: 4.7939
# Epoch 17/500
# 614/614 [==============================] - 0s 128us/sample - loss: 20.2578 - y1_output_loss: 7.8528 - y2_output_loss: 12.3693 - y1_output_root_mean_squared_error: 2.8125 - y2_output_root_mean_squared_error: 3.5139 - val_loss: 34.2171 - val_y1_output_loss: 8.7135 - val_y2_output_loss: 25.5062 - val_y1_output_root_mean_squared_error: 2.9315 - val_y2_output_root_mean_squared_error: 5.0620
# Epoch 18/500
# 614/614 [==============================] - 0s 127us/sample - loss: 19.5355 - y1_output_loss: 7.1647 - y2_output_loss: 12.2783 - y1_output_root_mean_squared_error: 2.6790 - y2_output_root_mean_squared_error: 3.5155 - val_loss: 18.0378 - val_y1_output_loss: 8.3802 - val_y2_output_loss: 10.1022 - val_y1_output_root_mean_squared_error: 2.8326 - val_y2_output_root_mean_squared_error: 3.1645
# Epoch 19/500
# 614/614 [==============================] - 0s 127us/sample - loss: 18.9684 - y1_output_loss: 7.0236 - y2_output_loss: 11.7720 - y1_output_root_mean_squared_error: 2.6619 - y2_output_root_mean_squared_error: 3.4471 - val_loss: 16.4542 - val_y1_output_loss: 6.4761 - val_y2_output_loss: 9.9606 - val_y1_output_root_mean_squared_error: 2.5254 - val_y2_output_root_mean_squared_error: 3.1743
# Epoch 20/500
# 614/614 [==============================] - 0s 127us/sample - loss: 19.5078 - y1_output_loss: 7.5078 - y2_output_loss: 11.9785 - y1_output_root_mean_squared_error: 2.7458 - y2_output_root_mean_squared_error: 3.4596 - val_loss: 22.0171 - val_y1_output_loss: 8.5263 - val_y2_output_loss: 13.3908 - val_y1_output_root_mean_squared_error: 2.9122 - val_y2_output_root_mean_squared_error: 3.6792
# Epoch 21/500
# 614/614 [==============================] - 0s 127us/sample - loss: 20.0335 - y1_output_loss: 7.3020 - y2_output_loss: 12.7267 - y1_output_root_mean_squared_error: 2.7037 - y2_output_root_mean_squared_error: 3.5670 - val_loss: 15.6576 - val_y1_output_loss: 6.5295 - val_y2_output_loss: 9.2930 - val_y1_output_root_mean_squared_error: 2.5271 - val_y2_output_root_mean_squared_error: 3.0449
# Epoch 22/500
# 614/614 [==============================] - 0s 127us/sample - loss: 16.9960 - y1_output_loss: 6.9309 - y2_output_loss: 10.7181 - y1_output_root_mean_squared_error: 2.5998 - y2_output_root_mean_squared_error: 3.1996 - val_loss: 152.3270 - val_y1_output_loss: 43.3060 - val_y2_output_loss: 104.2491 - val_y1_output_root_mean_squared_error: 6.7054 - val_y2_output_root_mean_squared_error: 10.3617
# Epoch 23/500
# 614/614 [==============================] - 0s 127us/sample - loss: 20.6410 - y1_output_loss: 7.5922 - y2_output_loss: 12.9041 - y1_output_root_mean_squared_error: 2.7645 - y2_output_root_mean_squared_error: 3.6053 - val_loss: 15.5482 - val_y1_output_loss: 6.2272 - val_y2_output_loss: 9.5275 - val_y1_output_root_mean_squared_error: 2.4553 - val_y2_output_root_mean_squared_error: 3.0854
# Epoch 24/500
# 614/614 [==============================] - 0s 128us/sample - loss: 16.7491 - y1_output_loss: 6.3223 - y2_output_loss: 10.3293 - y1_output_root_mean_squared_error: 2.5169 - y2_output_root_mean_squared_error: 3.2271 - val_loss: 38.4881 - val_y1_output_loss: 12.3955 - val_y2_output_loss: 25.0458 - val_y1_output_root_mean_squared_error: 3.5691 - val_y2_output_root_mean_squared_error: 5.0744
# Epoch 25/500
# 614/614 [==============================] - 0s 128us/sample - loss: 17.4220 - y1_output_loss: 6.8096 - y2_output_loss: 10.4977 - y1_output_root_mean_squared_error: 2.6190 - y2_output_root_mean_squared_error: 3.2500 - val_loss: 13.1217 - val_y1_output_loss: 5.3215 - val_y2_output_loss: 7.8973 - val_y1_output_root_mean_squared_error: 2.2806 - val_y2_output_root_mean_squared_error: 2.8144
# Epoch 26/500
# 614/614 [==============================] - 0s 128us/sample - loss: 17.9206 - y1_output_loss: 6.8770 - y2_output_loss: 11.4831 - y1_output_root_mean_squared_error: 2.5722 - y2_output_root_mean_squared_error: 3.3622 - val_loss: 110.1457 - val_y1_output_loss: 31.3711 - val_y2_output_loss: 75.3043 - val_y1_output_root_mean_squared_error: 5.6993 - val_y2_output_root_mean_squared_error: 8.8127
# Epoch 27/500
# 614/614 [==============================] - 0s 129us/sample - loss: 16.5036 - y1_output_loss: 6.3859 - y2_output_loss: 9.9961 - y1_output_root_mean_squared_error: 2.5372 - y2_output_root_mean_squared_error: 3.1727 - val_loss: 12.5742 - val_y1_output_loss: 5.1141 - val_y2_output_loss: 7.5310 - val_y1_output_root_mean_squared_error: 2.2374 - val_y2_output_root_mean_squared_error: 2.7511
# Epoch 28/500
# 614/614 [==============================] - 0s 128us/sample - loss: 14.7058 - y1_output_loss: 5.6364 - y2_output_loss: 8.9830 - y1_output_root_mean_squared_error: 2.3816 - y2_output_root_mean_squared_error: 3.0056 - val_loss: 11.7635 - val_y1_output_loss: 4.9812 - val_y2_output_loss: 7.0438 - val_y1_output_root_mean_squared_error: 2.1832 - val_y2_output_root_mean_squared_error: 2.6452
# Epoch 29/500
# 614/614 [==============================] - 0s 132us/sample - loss: 14.5409 - y1_output_loss: 5.5444 - y2_output_loss: 8.9283 - y1_output_root_mean_squared_error: 2.3655 - y2_output_root_mean_squared_error: 2.9909 - val_loss: 14.5133 - val_y1_output_loss: 5.6637 - val_y2_output_loss: 9.1653 - val_y1_output_root_mean_squared_error: 2.3371 - val_y2_output_root_mean_squared_error: 3.0085
# Epoch 30/500
# 614/614 [==============================] - 0s 134us/sample - loss: 14.7910 - y1_output_loss: 5.5013 - y2_output_loss: 9.1782 - y1_output_root_mean_squared_error: 2.3537 - y2_output_root_mean_squared_error: 3.0416 - val_loss: 13.5988 - val_y1_output_loss: 4.3803 - val_y2_output_loss: 9.1533 - val_y1_output_root_mean_squared_error: 2.0672 - val_y2_output_root_mean_squared_error: 3.0538
# Epoch 31/500
# 614/614 [==============================] - 0s 127us/sample - loss: 14.8162 - y1_output_loss: 5.4124 - y2_output_loss: 9.3368 - y1_output_root_mean_squared_error: 2.3356 - y2_output_root_mean_squared_error: 3.0596 - val_loss: 20.3875 - val_y1_output_loss: 6.1064 - val_y2_output_loss: 14.5116 - val_y1_output_root_mean_squared_error: 2.4363 - val_y2_output_root_mean_squared_error: 3.8016
# Epoch 32/500
# 614/614 [==============================] - 0s 128us/sample - loss: 17.6477 - y1_output_loss: 5.8817 - y2_output_loss: 11.7735 - y1_output_root_mean_squared_error: 2.4329 - y2_output_root_mean_squared_error: 3.4247 - val_loss: 19.9129 - val_y1_output_loss: 6.7013 - val_y2_output_loss: 13.8612 - val_y1_output_root_mean_squared_error: 2.5152 - val_y2_output_root_mean_squared_error: 3.6860
# Epoch 33/500
# 614/614 [==============================] - 0s 128us/sample - loss: 13.0291 - y1_output_loss: 4.9133 - y2_output_loss: 8.0423 - y1_output_root_mean_squared_error: 2.2201 - y2_output_root_mean_squared_error: 2.8461 - val_loss: 10.2780 - val_y1_output_loss: 4.2350 - val_y2_output_loss: 6.2790 - val_y1_output_root_mean_squared_error: 2.0136 - val_y2_output_root_mean_squared_error: 2.4947
# Epoch 34/500
# 614/614 [==============================] - 0s 127us/sample - loss: 14.9083 - y1_output_loss: 5.3136 - y2_output_loss: 9.5951 - y1_output_root_mean_squared_error: 2.2957 - y2_output_root_mean_squared_error: 3.1045 - val_loss: 16.1062 - val_y1_output_loss: 5.5063 - val_y2_output_loss: 10.3128 - val_y1_output_root_mean_squared_error: 2.3518 - val_y2_output_root_mean_squared_error: 3.2520
# Epoch 35/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.5397 - y1_output_loss: 4.5549 - y2_output_loss: 8.0548 - y1_output_root_mean_squared_error: 2.1279 - y2_output_root_mean_squared_error: 2.8305 - val_loss: 13.2960 - val_y1_output_loss: 5.4067 - val_y2_output_loss: 7.8422 - val_y1_output_root_mean_squared_error: 2.3214 - val_y2_output_root_mean_squared_error: 2.8119
# Epoch 36/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.3830 - y1_output_loss: 4.6416 - y2_output_loss: 7.8950 - y1_output_root_mean_squared_error: 2.1402 - y2_output_root_mean_squared_error: 2.7933 - val_loss: 73.2438 - val_y1_output_loss: 19.7043 - val_y2_output_loss: 51.3364 - val_y1_output_root_mean_squared_error: 4.5198 - val_y2_output_root_mean_squared_error: 7.2674
# Epoch 37/500
# 614/614 [==============================] - 0s 126us/sample - loss: 12.4560 - y1_output_loss: 4.8789 - y2_output_loss: 7.6747 - y1_output_root_mean_squared_error: 2.2053 - y2_output_root_mean_squared_error: 2.7555 - val_loss: 22.9764 - val_y1_output_loss: 6.1666 - val_y2_output_loss: 17.1366 - val_y1_output_root_mean_squared_error: 2.4331 - val_y2_output_root_mean_squared_error: 4.1299
# Epoch 38/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.3817 - y1_output_loss: 5.0485 - y2_output_loss: 9.3776 - y1_output_root_mean_squared_error: 2.2356 - y2_output_root_mean_squared_error: 3.0633 - val_loss: 9.9444 - val_y1_output_loss: 4.4026 - val_y2_output_loss: 5.7157 - val_y1_output_root_mean_squared_error: 2.0592 - val_y2_output_root_mean_squared_error: 2.3883
# Epoch 39/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.4568 - y1_output_loss: 4.6024 - y2_output_loss: 8.8551 - y1_output_root_mean_squared_error: 2.1516 - y2_output_root_mean_squared_error: 2.9711 - val_loss: 21.0983 - val_y1_output_loss: 6.5860 - val_y2_output_loss: 14.8623 - val_y1_output_root_mean_squared_error: 2.5146 - val_y2_output_root_mean_squared_error: 3.8438
# Epoch 40/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.4862 - y1_output_loss: 4.1133 - y2_output_loss: 7.2791 - y1_output_root_mean_squared_error: 2.0349 - y2_output_root_mean_squared_error: 2.7102 - val_loss: 8.9514 - val_y1_output_loss: 3.7857 - val_y2_output_loss: 5.4308 - val_y1_output_root_mean_squared_error: 1.8917 - val_y2_output_root_mean_squared_error: 2.3179
# Epoch 41/500
# 614/614 [==============================] - 0s 129us/sample - loss: 10.8093 - y1_output_loss: 3.9438 - y2_output_loss: 6.9603 - y1_output_root_mean_squared_error: 1.9760 - y2_output_root_mean_squared_error: 2.6277 - val_loss: 16.6828 - val_y1_output_loss: 6.7566 - val_y2_output_loss: 9.4484 - val_y1_output_root_mean_squared_error: 2.6328 - val_y2_output_root_mean_squared_error: 3.1227
# Epoch 42/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.6921 - y1_output_loss: 4.1499 - y2_output_loss: 7.4721 - y1_output_root_mean_squared_error: 2.0440 - y2_output_root_mean_squared_error: 2.7412 - val_loss: 11.4056 - val_y1_output_loss: 4.2769 - val_y2_output_loss: 7.0743 - val_y1_output_root_mean_squared_error: 2.0562 - val_y2_output_root_mean_squared_error: 2.6791
# Epoch 43/500
# 614/614 [==============================] - 0s 137us/sample - loss: 12.5965 - y1_output_loss: 4.2838 - y2_output_loss: 8.2743 - y1_output_root_mean_squared_error: 2.0770 - y2_output_root_mean_squared_error: 2.8779 - val_loss: 9.0035 - val_y1_output_loss: 3.7712 - val_y2_output_loss: 5.3655 - val_y1_output_root_mean_squared_error: 1.9045 - val_y2_output_root_mean_squared_error: 2.3187
# Epoch 44/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.3416 - y1_output_loss: 3.7004 - y2_output_loss: 6.8471 - y1_output_root_mean_squared_error: 1.9245 - y2_output_root_mean_squared_error: 2.5764 - val_loss: 83.1106 - val_y1_output_loss: 17.9179 - val_y2_output_loss: 64.6819 - val_y1_output_root_mean_squared_error: 4.2142 - val_y2_output_root_mean_squared_error: 8.0840
# Epoch 45/500
# 614/614 [==============================] - 0s 130us/sample - loss: 16.2682 - y1_output_loss: 5.1875 - y2_output_loss: 11.1407 - y1_output_root_mean_squared_error: 2.2715 - y2_output_root_mean_squared_error: 3.3329 - val_loss: 12.3080 - val_y1_output_loss: 4.2907 - val_y2_output_loss: 8.0368 - val_y1_output_root_mean_squared_error: 2.0549 - val_y2_output_root_mean_squared_error: 2.8435
# Epoch 46/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.4176 - y1_output_loss: 4.2249 - y2_output_loss: 8.0970 - y1_output_root_mean_squared_error: 2.0616 - y2_output_root_mean_squared_error: 2.8579 - val_loss: 18.7966 - val_y1_output_loss: 5.5258 - val_y2_output_loss: 13.2794 - val_y1_output_root_mean_squared_error: 2.3269 - val_y2_output_root_mean_squared_error: 3.6582
# Epoch 47/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.6068 - y1_output_loss: 3.5043 - y2_output_loss: 6.0269 - y1_output_root_mean_squared_error: 1.8789 - y2_output_root_mean_squared_error: 2.4651 - val_loss: 7.8229 - val_y1_output_loss: 2.8659 - val_y2_output_loss: 5.0035 - val_y1_output_root_mean_squared_error: 1.6625 - val_y2_output_root_mean_squared_error: 2.2492
# Epoch 48/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.5888 - y1_output_loss: 3.0929 - y2_output_loss: 5.4802 - y1_output_root_mean_squared_error: 1.7605 - y2_output_root_mean_squared_error: 2.3430 - val_loss: 11.3348 - val_y1_output_loss: 4.0662 - val_y2_output_loss: 7.2266 - val_y1_output_root_mean_squared_error: 2.0057 - val_y2_output_root_mean_squared_error: 2.7040
# Epoch 49/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.0774 - y1_output_loss: 3.2968 - y2_output_loss: 6.7998 - y1_output_root_mean_squared_error: 1.8080 - y2_output_root_mean_squared_error: 2.6093 - val_loss: 17.4438 - val_y1_output_loss: 4.8198 - val_y2_output_loss: 12.2273 - val_y1_output_root_mean_squared_error: 2.2121 - val_y2_output_root_mean_squared_error: 3.5427
# Epoch 50/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.1631 - y1_output_loss: 3.5490 - y2_output_loss: 6.6536 - y1_output_root_mean_squared_error: 1.8588 - y2_output_root_mean_squared_error: 2.5900 - val_loss: 24.2897 - val_y1_output_loss: 7.7601 - val_y2_output_loss: 15.8284 - val_y1_output_root_mean_squared_error: 2.8306 - val_y2_output_root_mean_squared_error: 4.0345
# Epoch 51/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.1482 - y1_output_loss: 2.8996 - y2_output_loss: 5.3469 - y1_output_root_mean_squared_error: 1.6968 - y2_output_root_mean_squared_error: 2.2955 - val_loss: 13.6665 - val_y1_output_loss: 4.8054 - val_y2_output_loss: 8.5777 - val_y1_output_root_mean_squared_error: 2.2082 - val_y2_output_root_mean_squared_error: 2.9648
# Epoch 52/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.8786 - y1_output_loss: 2.9992 - y2_output_loss: 5.8828 - y1_output_root_mean_squared_error: 1.7396 - y2_output_root_mean_squared_error: 2.4192 - val_loss: 10.8688 - val_y1_output_loss: 2.9975 - val_y2_output_loss: 7.7577 - val_y1_output_root_mean_squared_error: 1.7330 - val_y2_output_root_mean_squared_error: 2.8045
# Epoch 53/500
# 614/614 [==============================] - 0s 129us/sample - loss: 11.9314 - y1_output_loss: 3.8995 - y2_output_loss: 8.0808 - y1_output_root_mean_squared_error: 1.9772 - y2_output_root_mean_squared_error: 2.8323 - val_loss: 26.2570 - val_y1_output_loss: 9.0412 - val_y2_output_loss: 17.0132 - val_y1_output_root_mean_squared_error: 3.0021 - val_y2_output_root_mean_squared_error: 4.1527
# Epoch 54/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.4078 - y1_output_loss: 3.1251 - y2_output_loss: 6.2379 - y1_output_root_mean_squared_error: 1.7685 - y2_output_root_mean_squared_error: 2.5060 - val_loss: 14.7994 - val_y1_output_loss: 4.0402 - val_y2_output_loss: 10.9127 - val_y1_output_root_mean_squared_error: 1.9685 - val_y2_output_root_mean_squared_error: 3.3052
# Epoch 55/500
# 614/614 [==============================] - 0s 129us/sample - loss: 10.7528 - y1_output_loss: 3.4300 - y2_output_loss: 7.2456 - y1_output_root_mean_squared_error: 1.8574 - y2_output_root_mean_squared_error: 2.7024 - val_loss: 7.4948 - val_y1_output_loss: 2.5338 - val_y2_output_loss: 4.9354 - val_y1_output_root_mean_squared_error: 1.5810 - val_y2_output_root_mean_squared_error: 2.2350
# Epoch 56/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.0773 - y1_output_loss: 3.1785 - y2_output_loss: 5.8605 - y1_output_root_mean_squared_error: 1.7847 - y2_output_root_mean_squared_error: 2.4273 - val_loss: 7.6845 - val_y1_output_loss: 2.5998 - val_y2_output_loss: 5.0777 - val_y1_output_root_mean_squared_error: 1.5956 - val_y2_output_root_mean_squared_error: 2.2669
# Epoch 57/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.2566 - y1_output_loss: 2.9666 - y2_output_loss: 6.2132 - y1_output_root_mean_squared_error: 1.7295 - y2_output_root_mean_squared_error: 2.5031 - val_loss: 10.6257 - val_y1_output_loss: 4.6675 - val_y2_output_loss: 6.0186 - val_y1_output_root_mean_squared_error: 2.1361 - val_y2_output_root_mean_squared_error: 2.4623
# Epoch 58/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.2891 - y1_output_loss: 3.1747 - y2_output_loss: 6.0867 - y1_output_root_mean_squared_error: 1.7788 - y2_output_root_mean_squared_error: 2.4749 - val_loss: 8.8626 - val_y1_output_loss: 3.2822 - val_y2_output_loss: 5.3661 - val_y1_output_root_mean_squared_error: 1.8231 - val_y2_output_root_mean_squared_error: 2.3535
# Epoch 59/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.3075 - y1_output_loss: 2.3934 - y2_output_loss: 4.9685 - y1_output_root_mean_squared_error: 1.5426 - y2_output_root_mean_squared_error: 2.2199 - val_loss: 8.3482 - val_y1_output_loss: 3.0503 - val_y2_output_loss: 5.1798 - val_y1_output_root_mean_squared_error: 1.7500 - val_y2_output_root_mean_squared_error: 2.2990
# Epoch 60/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.4030 - y1_output_loss: 2.9644 - y2_output_loss: 6.3714 - y1_output_root_mean_squared_error: 1.7244 - y2_output_root_mean_squared_error: 2.5356 - val_loss: 6.2482 - val_y1_output_loss: 2.3386 - val_y2_output_loss: 3.9410 - val_y1_output_root_mean_squared_error: 1.5017 - val_y2_output_root_mean_squared_error: 1.9982
# Epoch 61/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.5367 - y1_output_loss: 2.5999 - y2_output_loss: 5.9125 - y1_output_root_mean_squared_error: 1.6103 - y2_output_root_mean_squared_error: 2.4380 - val_loss: 10.0181 - val_y1_output_loss: 3.6290 - val_y2_output_loss: 6.2735 - val_y1_output_root_mean_squared_error: 1.9016 - val_y2_output_root_mean_squared_error: 2.5303
# Epoch 62/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.3555 - y1_output_loss: 2.5572 - y2_output_loss: 5.8564 - y1_output_root_mean_squared_error: 1.6031 - y2_output_root_mean_squared_error: 2.4053 - val_loss: 7.4399 - val_y1_output_loss: 2.4830 - val_y2_output_loss: 4.9637 - val_y1_output_root_mean_squared_error: 1.5689 - val_y2_output_root_mean_squared_error: 2.2313
# Epoch 63/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.5189 - y1_output_loss: 2.9053 - y2_output_loss: 6.5574 - y1_output_root_mean_squared_error: 1.7054 - y2_output_root_mean_squared_error: 2.5711 - val_loss: 8.4675 - val_y1_output_loss: 3.6105 - val_y2_output_loss: 4.6152 - val_y1_output_root_mean_squared_error: 1.9254 - val_y2_output_root_mean_squared_error: 2.1818
# Epoch 64/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.8170 - y1_output_loss: 2.3025 - y2_output_loss: 4.4774 - y1_output_root_mean_squared_error: 1.5180 - y2_output_root_mean_squared_error: 2.1243 - val_loss: 6.1174 - val_y1_output_loss: 2.3386 - val_y2_output_loss: 3.9050 - val_y1_output_root_mean_squared_error: 1.4844 - val_y2_output_root_mean_squared_error: 1.9783
# Epoch 65/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.4277 - y1_output_loss: 2.6019 - y2_output_loss: 4.8427 - y1_output_root_mean_squared_error: 1.6159 - y2_output_root_mean_squared_error: 2.1947 - val_loss: 18.0250 - val_y1_output_loss: 4.1187 - val_y2_output_loss: 13.7417 - val_y1_output_root_mean_squared_error: 2.0125 - val_y2_output_root_mean_squared_error: 3.7383
# Epoch 66/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.1319 - y1_output_loss: 2.3462 - y2_output_loss: 4.8248 - y1_output_root_mean_squared_error: 1.5379 - y2_output_root_mean_squared_error: 2.1833 - val_loss: 6.3861 - val_y1_output_loss: 2.1939 - val_y2_output_loss: 4.2108 - val_y1_output_root_mean_squared_error: 1.4533 - val_y2_output_root_mean_squared_error: 2.0674
# Epoch 67/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.0027 - y1_output_loss: 2.5859 - y2_output_loss: 5.3748 - y1_output_root_mean_squared_error: 1.6096 - y2_output_root_mean_squared_error: 2.3263 - val_loss: 7.9243 - val_y1_output_loss: 2.0970 - val_y2_output_loss: 5.6262 - val_y1_output_root_mean_squared_error: 1.4494 - val_y2_output_root_mean_squared_error: 2.4132
# Epoch 68/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.9869 - y1_output_loss: 2.2336 - y2_output_loss: 4.7681 - y1_output_root_mean_squared_error: 1.4982 - y2_output_root_mean_squared_error: 2.1777 - val_loss: 11.7978 - val_y1_output_loss: 2.7771 - val_y2_output_loss: 8.9972 - val_y1_output_root_mean_squared_error: 1.6470 - val_y2_output_root_mean_squared_error: 3.0141
# Epoch 69/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.4172 - y1_output_loss: 2.1618 - y2_output_loss: 4.2694 - y1_output_root_mean_squared_error: 1.4562 - y2_output_root_mean_squared_error: 2.0728 - val_loss: 6.7883 - val_y1_output_loss: 2.6048 - val_y2_output_loss: 4.0898 - val_y1_output_root_mean_squared_error: 1.6130 - val_y2_output_root_mean_squared_error: 2.0461
# Epoch 70/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.0495 - y1_output_loss: 2.1592 - y2_output_loss: 3.8799 - y1_output_root_mean_squared_error: 1.4751 - y2_output_root_mean_squared_error: 1.9682 - val_loss: 6.5207 - val_y1_output_loss: 2.2003 - val_y2_output_loss: 4.3953 - val_y1_output_root_mean_squared_error: 1.4517 - val_y2_output_root_mean_squared_error: 2.1008
# Epoch 71/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.4390 - y1_output_loss: 2.0460 - y2_output_loss: 4.3933 - y1_output_root_mean_squared_error: 1.4212 - y2_output_root_mean_squared_error: 2.1022 - val_loss: 5.8706 - val_y1_output_loss: 2.1631 - val_y2_output_loss: 3.7286 - val_y1_output_root_mean_squared_error: 1.4425 - val_y2_output_root_mean_squared_error: 1.9467
# Epoch 72/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.9110 - y1_output_loss: 1.9685 - y2_output_loss: 3.8972 - y1_output_root_mean_squared_error: 1.4077 - y2_output_root_mean_squared_error: 1.9823 - val_loss: 6.0627 - val_y1_output_loss: 2.2420 - val_y2_output_loss: 3.6554 - val_y1_output_root_mean_squared_error: 1.5129 - val_y2_output_root_mean_squared_error: 1.9426
# Epoch 73/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.9512 - y1_output_loss: 2.2604 - y2_output_loss: 4.6662 - y1_output_root_mean_squared_error: 1.5078 - y2_output_root_mean_squared_error: 2.1628 - val_loss: 12.5558 - val_y1_output_loss: 3.4021 - val_y2_output_loss: 9.3099 - val_y1_output_root_mean_squared_error: 1.8059 - val_y2_output_root_mean_squared_error: 3.0487
# Epoch 74/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.1308 - y1_output_loss: 1.8564 - y2_output_loss: 4.2642 - y1_output_root_mean_squared_error: 1.3690 - y2_output_root_mean_squared_error: 2.0632 - val_loss: 5.1925 - val_y1_output_loss: 1.8147 - val_y2_output_loss: 3.3961 - val_y1_output_root_mean_squared_error: 1.3257 - val_y2_output_root_mean_squared_error: 1.8534
# Epoch 75/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.4207 - y1_output_loss: 1.7955 - y2_output_loss: 3.6613 - y1_output_root_mean_squared_error: 1.3234 - y2_output_root_mean_squared_error: 1.9156 - val_loss: 6.2361 - val_y1_output_loss: 2.5831 - val_y2_output_loss: 3.7191 - val_y1_output_root_mean_squared_error: 1.5783 - val_y2_output_root_mean_squared_error: 1.9352
# Epoch 76/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.2401 - y1_output_loss: 1.7798 - y2_output_loss: 4.4599 - y1_output_root_mean_squared_error: 1.3393 - y2_output_root_mean_squared_error: 2.1086 - val_loss: 7.8392 - val_y1_output_loss: 2.5982 - val_y2_output_loss: 5.2894 - val_y1_output_root_mean_squared_error: 1.5899 - val_y2_output_root_mean_squared_error: 2.3047
# Epoch 77/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.8553 - y1_output_loss: 1.7146 - y2_output_loss: 4.1759 - y1_output_root_mean_squared_error: 1.3066 - y2_output_root_mean_squared_error: 2.0367 - val_loss: 15.1385 - val_y1_output_loss: 2.2478 - val_y2_output_loss: 12.4449 - val_y1_output_root_mean_squared_error: 1.5075 - val_y2_output_root_mean_squared_error: 3.5869
# Epoch 78/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.8240 - y1_output_loss: 1.8380 - y2_output_loss: 3.9445 - y1_output_root_mean_squared_error: 1.3604 - y2_output_root_mean_squared_error: 1.9933 - val_loss: 5.0365 - val_y1_output_loss: 1.8422 - val_y2_output_loss: 3.1342 - val_y1_output_root_mean_squared_error: 1.3544 - val_y2_output_root_mean_squared_error: 1.7894
# Epoch 79/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.9446 - y1_output_loss: 1.7343 - y2_output_loss: 4.2103 - y1_output_root_mean_squared_error: 1.3180 - y2_output_root_mean_squared_error: 2.0512 - val_loss: 5.9495 - val_y1_output_loss: 1.8950 - val_y2_output_loss: 4.0921 - val_y1_output_root_mean_squared_error: 1.3534 - val_y2_output_root_mean_squared_error: 2.0293
# Epoch 80/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.0453 - y1_output_loss: 1.5150 - y2_output_loss: 3.5294 - y1_output_root_mean_squared_error: 1.2300 - y2_output_root_mean_squared_error: 1.8795 - val_loss: 9.8140 - val_y1_output_loss: 2.9449 - val_y2_output_loss: 6.5438 - val_y1_output_root_mean_squared_error: 1.7410 - val_y2_output_root_mean_squared_error: 2.6044
# Epoch 81/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.6473 - y1_output_loss: 1.9762 - y2_output_loss: 4.6673 - y1_output_root_mean_squared_error: 1.4071 - y2_output_root_mean_squared_error: 2.1604 - val_loss: 8.8066 - val_y1_output_loss: 2.5775 - val_y2_output_loss: 5.9868 - val_y1_output_root_mean_squared_error: 1.6172 - val_y2_output_root_mean_squared_error: 2.4883
# Epoch 82/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.3325 - y1_output_loss: 1.3546 - y2_output_loss: 2.9794 - y1_output_root_mean_squared_error: 1.1522 - y2_output_root_mean_squared_error: 1.7335 - val_loss: 5.4762 - val_y1_output_loss: 1.6548 - val_y2_output_loss: 3.7402 - val_y1_output_root_mean_squared_error: 1.2714 - val_y2_output_root_mean_squared_error: 1.9646
# Epoch 83/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.4385 - y1_output_loss: 1.4317 - y2_output_loss: 3.1342 - y1_output_root_mean_squared_error: 1.1989 - y2_output_root_mean_squared_error: 1.7324 - val_loss: 33.3105 - val_y1_output_loss: 7.0036 - val_y2_output_loss: 25.2199 - val_y1_output_root_mean_squared_error: 2.6909 - val_y2_output_root_mean_squared_error: 5.1058
# Epoch 84/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.0846 - y1_output_loss: 1.4099 - y2_output_loss: 3.6567 - y1_output_root_mean_squared_error: 1.1863 - y2_output_root_mean_squared_error: 1.9177 - val_loss: 4.7781 - val_y1_output_loss: 1.6068 - val_y2_output_loss: 3.0848 - val_y1_output_root_mean_squared_error: 1.2722 - val_y2_output_root_mean_squared_error: 1.7775
# Epoch 85/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.8581 - y1_output_loss: 1.1229 - y2_output_loss: 2.7041 - y1_output_root_mean_squared_error: 1.0639 - y2_output_root_mean_squared_error: 1.6511 - val_loss: 3.6106 - val_y1_output_loss: 1.2339 - val_y2_output_loss: 2.3667 - val_y1_output_root_mean_squared_error: 1.0980 - val_y2_output_root_mean_squared_error: 1.5508
# Epoch 86/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.7725 - y1_output_loss: 1.1237 - y2_output_loss: 2.6222 - y1_output_root_mean_squared_error: 1.0647 - y2_output_root_mean_squared_error: 1.6245 - val_loss: 4.0215 - val_y1_output_loss: 1.2473 - val_y2_output_loss: 2.7837 - val_y1_output_root_mean_squared_error: 1.1034 - val_y2_output_root_mean_squared_error: 1.6745
# Epoch 87/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.8114 - y1_output_loss: 1.1189 - y2_output_loss: 2.6877 - y1_output_root_mean_squared_error: 1.0584 - y2_output_root_mean_squared_error: 1.6405 - val_loss: 6.3375 - val_y1_output_loss: 1.5596 - val_y2_output_loss: 4.5646 - val_y1_output_root_mean_squared_error: 1.2668 - val_y2_output_root_mean_squared_error: 2.1755
# Epoch 88/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.8763 - y1_output_loss: 1.1853 - y2_output_loss: 2.6860 - y1_output_root_mean_squared_error: 1.0814 - y2_output_root_mean_squared_error: 1.6453 - val_loss: 3.5722 - val_y1_output_loss: 0.8629 - val_y2_output_loss: 2.6962 - val_y1_output_root_mean_squared_error: 0.9248 - val_y2_output_root_mean_squared_error: 1.6483
# Epoch 89/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.8037 - y1_output_loss: 1.1619 - y2_output_loss: 2.6445 - y1_output_root_mean_squared_error: 1.0803 - y2_output_root_mean_squared_error: 1.6238 - val_loss: 4.8569 - val_y1_output_loss: 1.5707 - val_y2_output_loss: 3.3029 - val_y1_output_root_mean_squared_error: 1.2298 - val_y2_output_root_mean_squared_error: 1.8288
# Epoch 90/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.9462 - y1_output_loss: 1.0794 - y2_output_loss: 2.8418 - y1_output_root_mean_squared_error: 1.0412 - y2_output_root_mean_squared_error: 1.6918 - val_loss: 3.8502 - val_y1_output_loss: 1.0212 - val_y2_output_loss: 2.7932 - val_y1_output_root_mean_squared_error: 1.0017 - val_y2_output_root_mean_squared_error: 1.6872
# Epoch 91/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.4823 - y1_output_loss: 1.2476 - y2_output_loss: 4.2067 - y1_output_root_mean_squared_error: 1.1208 - y2_output_root_mean_squared_error: 2.0558 - val_loss: 6.2830 - val_y1_output_loss: 0.9841 - val_y2_output_loss: 5.2740 - val_y1_output_root_mean_squared_error: 0.9865 - val_y2_output_root_mean_squared_error: 2.3043
# Epoch 92/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.9997 - y1_output_loss: 1.6863 - y2_output_loss: 4.2804 - y1_output_root_mean_squared_error: 1.3005 - y2_output_root_mean_squared_error: 2.0757 - val_loss: 6.5906 - val_y1_output_loss: 1.2239 - val_y2_output_loss: 5.3971 - val_y1_output_root_mean_squared_error: 1.0904 - val_y2_output_root_mean_squared_error: 2.3242
# Epoch 93/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.4148 - y1_output_loss: 1.0646 - y2_output_loss: 3.3222 - y1_output_root_mean_squared_error: 1.0357 - y2_output_root_mean_squared_error: 1.8282 - val_loss: 3.8839 - val_y1_output_loss: 1.0864 - val_y2_output_loss: 2.7413 - val_y1_output_root_mean_squared_error: 1.0483 - val_y2_output_root_mean_squared_error: 1.6688
# Epoch 94/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.4303 - y1_output_loss: 0.9231 - y2_output_loss: 2.5671 - y1_output_root_mean_squared_error: 0.9572 - y2_output_root_mean_squared_error: 1.5856 - val_loss: 9.2572 - val_y1_output_loss: 2.7018 - val_y2_output_loss: 6.2329 - val_y1_output_root_mean_squared_error: 1.6708 - val_y2_output_root_mean_squared_error: 2.5428
# Epoch 95/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4746 - y1_output_loss: 0.9588 - y2_output_loss: 2.4867 - y1_output_root_mean_squared_error: 0.9828 - y2_output_root_mean_squared_error: 1.5839 - val_loss: 4.4859 - val_y1_output_loss: 0.9347 - val_y2_output_loss: 3.4034 - val_y1_output_root_mean_squared_error: 0.9802 - val_y2_output_root_mean_squared_error: 1.8775
# Epoch 96/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.8950 - y1_output_loss: 0.8264 - y2_output_loss: 2.0513 - y1_output_root_mean_squared_error: 0.9121 - y2_output_root_mean_squared_error: 1.4363 - val_loss: 2.9819 - val_y1_output_loss: 0.7445 - val_y2_output_loss: 2.2285 - val_y1_output_root_mean_squared_error: 0.8523 - val_y2_output_root_mean_squared_error: 1.5019
# Epoch 97/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.6653 - y1_output_loss: 0.6787 - y2_output_loss: 1.9760 - y1_output_root_mean_squared_error: 0.8248 - y2_output_root_mean_squared_error: 1.4089 - val_loss: 3.2170 - val_y1_output_loss: 0.8322 - val_y2_output_loss: 2.3409 - val_y1_output_root_mean_squared_error: 0.9111 - val_y2_output_root_mean_squared_error: 1.5449
# Epoch 98/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.7991 - y1_output_loss: 0.8978 - y2_output_loss: 2.8885 - y1_output_root_mean_squared_error: 0.9458 - y2_output_root_mean_squared_error: 1.7043 - val_loss: 4.2754 - val_y1_output_loss: 1.7967 - val_y2_output_loss: 2.4635 - val_y1_output_root_mean_squared_error: 1.3368 - val_y2_output_root_mean_squared_error: 1.5775
# Epoch 99/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.4312 - y1_output_loss: 0.9667 - y2_output_loss: 2.4955 - y1_output_root_mean_squared_error: 0.9739 - y2_output_root_mean_squared_error: 1.5757 - val_loss: 19.1891 - val_y1_output_loss: 6.3488 - val_y2_output_loss: 12.4832 - val_y1_output_root_mean_squared_error: 2.5439 - val_y2_output_root_mean_squared_error: 3.5662
# Epoch 100/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.7251 - y1_output_loss: 0.7412 - y2_output_loss: 1.9867 - y1_output_root_mean_squared_error: 0.8590 - y2_output_root_mean_squared_error: 1.4097 - val_loss: 9.3043 - val_y1_output_loss: 2.7187 - val_y2_output_loss: 6.5231 - val_y1_output_root_mean_squared_error: 1.6480 - val_y2_output_root_mean_squared_error: 2.5668
# Epoch 101/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.5259 - y1_output_loss: 0.8152 - y2_output_loss: 2.6957 - y1_output_root_mean_squared_error: 0.9056 - y2_output_root_mean_squared_error: 1.6449 - val_loss: 4.0311 - val_y1_output_loss: 0.8779 - val_y2_output_loss: 3.0251 - val_y1_output_root_mean_squared_error: 0.9489 - val_y2_output_root_mean_squared_error: 1.7694
# Epoch 102/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.3054 - y1_output_loss: 0.7767 - y2_output_loss: 2.5096 - y1_output_root_mean_squared_error: 0.8840 - y2_output_root_mean_squared_error: 1.5887 - val_loss: 2.8016 - val_y1_output_loss: 0.5515 - val_y2_output_loss: 2.1917 - val_y1_output_root_mean_squared_error: 0.7401 - val_y2_output_root_mean_squared_error: 1.5013
# Epoch 103/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.0976 - y1_output_loss: 0.7818 - y2_output_loss: 2.2979 - y1_output_root_mean_squared_error: 0.8847 - y2_output_root_mean_squared_error: 1.5215 - val_loss: 3.2375 - val_y1_output_loss: 0.9395 - val_y2_output_loss: 2.2865 - val_y1_output_root_mean_squared_error: 0.9602 - val_y2_output_root_mean_squared_error: 1.5217
# Epoch 104/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.6537 - y1_output_loss: 0.7630 - y2_output_loss: 1.9304 - y1_output_root_mean_squared_error: 0.8728 - y2_output_root_mean_squared_error: 1.3755 - val_loss: 3.6837 - val_y1_output_loss: 0.5214 - val_y2_output_loss: 3.1488 - val_y1_output_root_mean_squared_error: 0.7203 - val_y2_output_root_mean_squared_error: 1.7790
# Epoch 105/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.8187 - y1_output_loss: 0.7316 - y2_output_loss: 2.0792 - y1_output_root_mean_squared_error: 0.8543 - y2_output_root_mean_squared_error: 1.4453 - val_loss: 7.4666 - val_y1_output_loss: 1.6641 - val_y2_output_loss: 5.5564 - val_y1_output_root_mean_squared_error: 1.3092 - val_y2_output_root_mean_squared_error: 2.3984
# Epoch 106/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.7195 - y1_output_loss: 0.6547 - y2_output_loss: 2.0494 - y1_output_root_mean_squared_error: 0.8094 - y2_output_root_mean_squared_error: 1.4368 - val_loss: 2.2964 - val_y1_output_loss: 0.4367 - val_y2_output_loss: 1.8392 - val_y1_output_root_mean_squared_error: 0.6532 - val_y2_output_root_mean_squared_error: 1.3674
# Epoch 107/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.2992 - y1_output_loss: 0.5363 - y2_output_loss: 1.7523 - y1_output_root_mean_squared_error: 0.7340 - y2_output_root_mean_squared_error: 1.3268 - val_loss: 2.7767 - val_y1_output_loss: 0.5978 - val_y2_output_loss: 2.1529 - val_y1_output_root_mean_squared_error: 0.7693 - val_y2_output_root_mean_squared_error: 1.4781
# Epoch 108/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.5236 - y1_output_loss: 0.9029 - y2_output_loss: 2.5904 - y1_output_root_mean_squared_error: 0.9546 - y2_output_root_mean_squared_error: 1.6163 - val_loss: 4.4200 - val_y1_output_loss: 1.3069 - val_y2_output_loss: 2.9802 - val_y1_output_root_mean_squared_error: 1.1622 - val_y2_output_root_mean_squared_error: 1.7520
# Epoch 109/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.5392 - y1_output_loss: 0.8044 - y2_output_loss: 2.7708 - y1_output_root_mean_squared_error: 0.8925 - y2_output_root_mean_squared_error: 1.6561 - val_loss: 11.7292 - val_y1_output_loss: 1.1142 - val_y2_output_loss: 10.4851 - val_y1_output_root_mean_squared_error: 1.0629 - val_y2_output_root_mean_squared_error: 3.2557
# Epoch 110/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.6082 - y1_output_loss: 0.7456 - y2_output_loss: 1.8688 - y1_output_root_mean_squared_error: 0.8600 - y2_output_root_mean_squared_error: 1.3669 - val_loss: 2.5959 - val_y1_output_loss: 0.4736 - val_y2_output_loss: 2.0844 - val_y1_output_root_mean_squared_error: 0.6815 - val_y2_output_root_mean_squared_error: 1.4600
# Epoch 111/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.7784 - y1_output_loss: 0.6888 - y2_output_loss: 2.0815 - y1_output_root_mean_squared_error: 0.8273 - y2_output_root_mean_squared_error: 1.4471 - val_loss: 6.4747 - val_y1_output_loss: 2.2403 - val_y2_output_loss: 4.2276 - val_y1_output_root_mean_squared_error: 1.4974 - val_y2_output_root_mean_squared_error: 2.0573
# Epoch 112/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.1934 - y1_output_loss: 0.7208 - y2_output_loss: 2.4592 - y1_output_root_mean_squared_error: 0.8523 - y2_output_root_mean_squared_error: 1.5707 - val_loss: 4.3772 - val_y1_output_loss: 0.9985 - val_y2_output_loss: 3.3896 - val_y1_output_root_mean_squared_error: 0.9943 - val_y2_output_root_mean_squared_error: 1.8408
# Epoch 113/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.8814 - y1_output_loss: 0.6474 - y2_output_loss: 2.2393 - y1_output_root_mean_squared_error: 0.8031 - y2_output_root_mean_squared_error: 1.4955 - val_loss: 4.1790 - val_y1_output_loss: 0.9685 - val_y2_output_loss: 3.0991 - val_y1_output_root_mean_squared_error: 0.9944 - val_y2_output_root_mean_squared_error: 1.7861
# Epoch 114/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.0930 - y1_output_loss: 0.5063 - y2_output_loss: 1.6019 - y1_output_root_mean_squared_error: 0.7129 - y2_output_root_mean_squared_error: 1.2589 - val_loss: 4.8597 - val_y1_output_loss: 0.6179 - val_y2_output_loss: 4.0963 - val_y1_output_root_mean_squared_error: 0.7901 - val_y2_output_root_mean_squared_error: 2.0580
# Epoch 115/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.4816 - y1_output_loss: 0.5965 - y2_output_loss: 1.8997 - y1_output_root_mean_squared_error: 0.7732 - y2_output_root_mean_squared_error: 1.3725 - val_loss: 7.8074 - val_y1_output_loss: 1.4983 - val_y2_output_loss: 6.3316 - val_y1_output_root_mean_squared_error: 1.2199 - val_y2_output_root_mean_squared_error: 2.5138
# Epoch 116/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.4099 - y1_output_loss: 0.5516 - y2_output_loss: 1.8379 - y1_output_root_mean_squared_error: 0.7448 - y2_output_root_mean_squared_error: 1.3621 - val_loss: 2.6272 - val_y1_output_loss: 0.6600 - val_y2_output_loss: 1.9539 - val_y1_output_root_mean_squared_error: 0.8136 - val_y2_output_root_mean_squared_error: 1.4019
# Epoch 117/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.1589 - y1_output_loss: 0.4575 - y2_output_loss: 1.7030 - y1_output_root_mean_squared_error: 0.6740 - y2_output_root_mean_squared_error: 1.3056 - val_loss: 9.1529 - val_y1_output_loss: 2.0397 - val_y2_output_loss: 7.0900 - val_y1_output_root_mean_squared_error: 1.4320 - val_y2_output_root_mean_squared_error: 2.6650
# Epoch 118/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.7912 - y1_output_loss: 0.7354 - y2_output_loss: 2.0440 - y1_output_root_mean_squared_error: 0.8617 - y2_output_root_mean_squared_error: 1.4313 - val_loss: 3.1082 - val_y1_output_loss: 0.6942 - val_y2_output_loss: 2.4303 - val_y1_output_root_mean_squared_error: 0.8361 - val_y2_output_root_mean_squared_error: 1.5521
# Epoch 119/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.7353 - y1_output_loss: 0.7507 - y2_output_loss: 1.9696 - y1_output_root_mean_squared_error: 0.8680 - y2_output_root_mean_squared_error: 1.4078 - val_loss: 2.9037 - val_y1_output_loss: 0.4153 - val_y2_output_loss: 2.4290 - val_y1_output_root_mean_squared_error: 0.6409 - val_y2_output_root_mean_squared_error: 1.5789
# Epoch 120/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4355 - y1_output_loss: 0.1227 - y2_output_loss: 0.3135 - y1_output_root_mean_squared_error: 0.3461 - y2_output_root_mean_squared_error: 0.5619 - val_loss: 1.5268 - val_y1_output_loss: 0.4638 - val_y2_output_loss: 1.0419 - val_y1_output_root_mean_squared_error: 0.6905 - val_y2_output_root_mean_squared_error: 1.0247
# Epoch 462/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4200 - y1_output_loss: 0.1219 - y2_output_loss: 0.2969 - y1_output_root_mean_squared_error: 0.3505 - y2_output_root_mean_squared_error: 0.5451 - val_loss: 0.7132 - val_y1_output_loss: 0.1843 - val_y2_output_loss: 0.5164 - val_y1_output_root_mean_squared_error: 0.4357 - val_y2_output_root_mean_squared_error: 0.7235
# Epoch 463/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3828 - y1_output_loss: 0.1049 - y2_output_loss: 0.2767 - y1_output_root_mean_squared_error: 0.3247 - y2_output_root_mean_squared_error: 0.5267 - val_loss: 0.7544 - val_y1_output_loss: 0.2417 - val_y2_output_loss: 0.5051 - val_y1_output_root_mean_squared_error: 0.4943 - val_y2_output_root_mean_squared_error: 0.7142
# Epoch 464/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5624 - y1_output_loss: 0.1205 - y2_output_loss: 0.4397 - y1_output_root_mean_squared_error: 0.3468 - y2_output_root_mean_squared_error: 0.6649 - val_loss: 0.8354 - val_y1_output_loss: 0.2239 - val_y2_output_loss: 0.6004 - val_y1_output_root_mean_squared_error: 0.4805 - val_y2_output_root_mean_squared_error: 0.7775
# Epoch 465/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5755 - y1_output_loss: 0.1404 - y2_output_loss: 0.4319 - y1_output_root_mean_squared_error: 0.3760 - y2_output_root_mean_squared_error: 0.6589 - val_loss: 1.0936 - val_y1_output_loss: 0.3683 - val_y2_output_loss: 0.7209 - val_y1_output_root_mean_squared_error: 0.6133 - val_y2_output_root_mean_squared_error: 0.8471
# Epoch 466/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3148 - y1_output_loss: 0.1008 - y2_output_loss: 0.2142 - y1_output_root_mean_squared_error: 0.3151 - y2_output_root_mean_squared_error: 0.4642 - val_loss: 1.6993 - val_y1_output_loss: 0.4322 - val_y2_output_loss: 1.2614 - val_y1_output_root_mean_squared_error: 0.6665 - val_y2_output_root_mean_squared_error: 1.1203
# Epoch 467/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4755 - y1_output_loss: 0.1249 - y2_output_loss: 0.3484 - y1_output_root_mean_squared_error: 0.3550 - y2_output_root_mean_squared_error: 0.5912 - val_loss: 1.0545 - val_y1_output_loss: 0.2314 - val_y2_output_loss: 0.7901 - val_y1_output_root_mean_squared_error: 0.4888 - val_y2_output_root_mean_squared_error: 0.9031
# Epoch 468/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4734 - y1_output_loss: 0.1351 - y2_output_loss: 0.3383 - y1_output_root_mean_squared_error: 0.3676 - y2_output_root_mean_squared_error: 0.5816 - val_loss: 1.8039 - val_y1_output_loss: 0.3976 - val_y2_output_loss: 1.4167 - val_y1_output_root_mean_squared_error: 0.6319 - val_y2_output_root_mean_squared_error: 1.1851
# Epoch 469/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4988 - y1_output_loss: 0.1380 - y2_output_loss: 0.3574 - y1_output_root_mean_squared_error: 0.3720 - y2_output_root_mean_squared_error: 0.6004 - val_loss: 0.7536 - val_y1_output_loss: 0.2242 - val_y2_output_loss: 0.5187 - val_y1_output_root_mean_squared_error: 0.4799 - val_y2_output_root_mean_squared_error: 0.7234
# Epoch 470/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4960 - y1_output_loss: 0.1286 - y2_output_loss: 0.3636 - y1_output_root_mean_squared_error: 0.3598 - y2_output_root_mean_squared_error: 0.6055 - val_loss: 0.7195 - val_y1_output_loss: 0.1949 - val_y2_output_loss: 0.5326 - val_y1_output_root_mean_squared_error: 0.4483 - val_y2_output_root_mean_squared_error: 0.7201
# Epoch 471/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3939 - y1_output_loss: 0.1142 - y2_output_loss: 0.2768 - y1_output_root_mean_squared_error: 0.3384 - y2_output_root_mean_squared_error: 0.5286 - val_loss: 0.9062 - val_y1_output_loss: 0.2408 - val_y2_output_loss: 0.6710 - val_y1_output_root_mean_squared_error: 0.4997 - val_y2_output_root_mean_squared_error: 0.8102
# Epoch 472/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3340 - y1_output_loss: 0.0997 - y2_output_loss: 0.2337 - y1_output_root_mean_squared_error: 0.3172 - y2_output_root_mean_squared_error: 0.4831 - val_loss: 0.7885 - val_y1_output_loss: 0.2544 - val_y2_output_loss: 0.5371 - val_y1_output_root_mean_squared_error: 0.5065 - val_y2_output_root_mean_squared_error: 0.7294
# Epoch 473/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4101 - y1_output_loss: 0.1096 - y2_output_loss: 0.2976 - y1_output_root_mean_squared_error: 0.3325 - y2_output_root_mean_squared_error: 0.5473 - val_loss: 1.2053 - val_y1_output_loss: 0.2728 - val_y2_output_loss: 0.9273 - val_y1_output_root_mean_squared_error: 0.5301 - val_y2_output_root_mean_squared_error: 0.9614
# Epoch 474/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3514 - y1_output_loss: 0.1114 - y2_output_loss: 0.2428 - y1_output_root_mean_squared_error: 0.3292 - y2_output_root_mean_squared_error: 0.4930 - val_loss: 1.2884 - val_y1_output_loss: 0.4026 - val_y2_output_loss: 0.8638 - val_y1_output_root_mean_squared_error: 0.6458 - val_y2_output_root_mean_squared_error: 0.9335
# Epoch 475/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4793 - y1_output_loss: 0.1338 - y2_output_loss: 0.3424 - y1_output_root_mean_squared_error: 0.3663 - y2_output_root_mean_squared_error: 0.5874 - val_loss: 0.7822 - val_y1_output_loss: 0.2117 - val_y2_output_loss: 0.5581 - val_y1_output_root_mean_squared_error: 0.4673 - val_y2_output_root_mean_squared_error: 0.7509
# Epoch 476/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4137 - y1_output_loss: 0.1149 - y2_output_loss: 0.2965 - y1_output_root_mean_squared_error: 0.3392 - y2_output_root_mean_squared_error: 0.5464 - val_loss: 0.7694 - val_y1_output_loss: 0.2374 - val_y2_output_loss: 0.5200 - val_y1_output_root_mean_squared_error: 0.4935 - val_y2_output_root_mean_squared_error: 0.7251
# Epoch 477/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3773 - y1_output_loss: 0.1105 - y2_output_loss: 0.2657 - y1_output_root_mean_squared_error: 0.3332 - y2_output_root_mean_squared_error: 0.5161 - val_loss: 0.8047 - val_y1_output_loss: 0.2262 - val_y2_output_loss: 0.5629 - val_y1_output_root_mean_squared_error: 0.4824 - val_y2_output_root_mean_squared_error: 0.7563
# Epoch 478/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3993 - y1_output_loss: 0.1155 - y2_output_loss: 0.2847 - y1_output_root_mean_squared_error: 0.3405 - y2_output_root_mean_squared_error: 0.5323 - val_loss: 0.9679 - val_y1_output_loss: 0.2480 - val_y2_output_loss: 0.6933 - val_y1_output_root_mean_squared_error: 0.5059 - val_y2_output_root_mean_squared_error: 0.8438
# Epoch 479/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3931 - y1_output_loss: 0.1076 - y2_output_loss: 0.2880 - y1_output_root_mean_squared_error: 0.3292 - y2_output_root_mean_squared_error: 0.5336 - val_loss: 2.5160 - val_y1_output_loss: 0.3372 - val_y2_output_loss: 2.1778 - val_y1_output_root_mean_squared_error: 0.5880 - val_y2_output_root_mean_squared_error: 1.4732
# Epoch 480/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4557 - y1_output_loss: 0.1137 - y2_output_loss: 0.3415 - y1_output_root_mean_squared_error: 0.3382 - y2_output_root_mean_squared_error: 0.5843 - val_loss: 0.7931 - val_y1_output_loss: 0.2234 - val_y2_output_loss: 0.5619 - val_y1_output_root_mean_squared_error: 0.4781 - val_y2_output_root_mean_squared_error: 0.7513
# Epoch 481/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3208 - y1_output_loss: 0.1048 - y2_output_loss: 0.2197 - y1_output_root_mean_squared_error: 0.3222 - y2_output_root_mean_squared_error: 0.4658 - val_loss: 0.8953 - val_y1_output_loss: 0.1948 - val_y2_output_loss: 0.6990 - val_y1_output_root_mean_squared_error: 0.4468 - val_y2_output_root_mean_squared_error: 0.8340
# Epoch 482/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3634 - y1_output_loss: 0.0990 - y2_output_loss: 0.2626 - y1_output_root_mean_squared_error: 0.3160 - y2_output_root_mean_squared_error: 0.5134 - val_loss: 0.7761 - val_y1_output_loss: 0.2014 - val_y2_output_loss: 0.5605 - val_y1_output_root_mean_squared_error: 0.4546 - val_y2_output_root_mean_squared_error: 0.7546
# Epoch 483/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4143 - y1_output_loss: 0.1094 - y2_output_loss: 0.3043 - y1_output_root_mean_squared_error: 0.3312 - y2_output_root_mean_squared_error: 0.5519 - val_loss: 1.1816 - val_y1_output_loss: 0.3536 - val_y2_output_loss: 0.8620 - val_y1_output_root_mean_squared_error: 0.5904 - val_y2_output_root_mean_squared_error: 0.9127
# Epoch 484/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3324 - y1_output_loss: 0.1006 - y2_output_loss: 0.2301 - y1_output_root_mean_squared_error: 0.3185 - y2_output_root_mean_squared_error: 0.4806 - val_loss: 0.7057 - val_y1_output_loss: 0.2072 - val_y2_output_loss: 0.4993 - val_y1_output_root_mean_squared_error: 0.4607 - val_y2_output_root_mean_squared_error: 0.7025
# Epoch 485/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3357 - y1_output_loss: 0.1047 - y2_output_loss: 0.2318 - y1_output_root_mean_squared_error: 0.3242 - y2_output_root_mean_squared_error: 0.4802 - val_loss: 0.8499 - val_y1_output_loss: 0.2031 - val_y2_output_loss: 0.6544 - val_y1_output_root_mean_squared_error: 0.4556 - val_y2_output_root_mean_squared_error: 0.8015
# Epoch 486/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4481 - y1_output_loss: 0.1271 - y2_output_loss: 0.3182 - y1_output_root_mean_squared_error: 0.3571 - y2_output_root_mean_squared_error: 0.5662 - val_loss: 0.7965 - val_y1_output_loss: 0.2514 - val_y2_output_loss: 0.5521 - val_y1_output_root_mean_squared_error: 0.5020 - val_y2_output_root_mean_squared_error: 0.7379
# Epoch 487/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3975 - y1_output_loss: 0.1106 - y2_output_loss: 0.2859 - y1_output_root_mean_squared_error: 0.3329 - y2_output_root_mean_squared_error: 0.5354 - val_loss: 0.7221 - val_y1_output_loss: 0.2166 - val_y2_output_loss: 0.4958 - val_y1_output_root_mean_squared_error: 0.4729 - val_y2_output_root_mean_squared_error: 0.7060
# Epoch 488/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3393 - y1_output_loss: 0.1035 - y2_output_loss: 0.2388 - y1_output_root_mean_squared_error: 0.3188 - y2_output_root_mean_squared_error: 0.4875 - val_loss: 0.7507 - val_y1_output_loss: 0.2256 - val_y2_output_loss: 0.5180 - val_y1_output_root_mean_squared_error: 0.4824 - val_y2_output_root_mean_squared_error: 0.7198
# Epoch 489/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3801 - y1_output_loss: 0.1030 - y2_output_loss: 0.2751 - y1_output_root_mean_squared_error: 0.3221 - y2_output_root_mean_squared_error: 0.5256 - val_loss: 1.1339 - val_y1_output_loss: 0.2087 - val_y2_output_loss: 0.9211 - val_y1_output_root_mean_squared_error: 0.4630 - val_y2_output_root_mean_squared_error: 0.9589
# Epoch 490/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4235 - y1_output_loss: 0.1203 - y2_output_loss: 0.3012 - y1_output_root_mean_squared_error: 0.3483 - y2_output_root_mean_squared_error: 0.5497 - val_loss: 0.8786 - val_y1_output_loss: 0.2685 - val_y2_output_loss: 0.6019 - val_y1_output_root_mean_squared_error: 0.5258 - val_y2_output_root_mean_squared_error: 0.7760
# Epoch 491/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3545 - y1_output_loss: 0.1123 - y2_output_loss: 0.2407 - y1_output_root_mean_squared_error: 0.3339 - y2_output_root_mean_squared_error: 0.4929 - val_loss: 0.8705 - val_y1_output_loss: 0.2245 - val_y2_output_loss: 0.6374 - val_y1_output_root_mean_squared_error: 0.4792 - val_y2_output_root_mean_squared_error: 0.8005
# Epoch 492/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4503 - y1_output_loss: 0.1131 - y2_output_loss: 0.3360 - y1_output_root_mean_squared_error: 0.3365 - y2_output_root_mean_squared_error: 0.5806 - val_loss: 1.0150 - val_y1_output_loss: 0.2533 - val_y2_output_loss: 0.7607 - val_y1_output_root_mean_squared_error: 0.5086 - val_y2_output_root_mean_squared_error: 0.8697
# Epoch 493/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4255 - y1_output_loss: 0.1061 - y2_output_loss: 0.3168 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.5651 - val_loss: 0.8129 - val_y1_output_loss: 0.1975 - val_y2_output_loss: 0.5915 - val_y1_output_root_mean_squared_error: 0.4526 - val_y2_output_root_mean_squared_error: 0.7797
# Epoch 494/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3683 - y1_output_loss: 0.1149 - y2_output_loss: 0.2536 - y1_output_root_mean_squared_error: 0.3392 - y2_output_root_mean_squared_error: 0.5033 - val_loss: 0.6706 - val_y1_output_loss: 0.1892 - val_y2_output_loss: 0.4824 - val_y1_output_root_mean_squared_error: 0.4413 - val_y2_output_root_mean_squared_error: 0.6898
# Epoch 495/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2792 - y1_output_loss: 0.0913 - y2_output_loss: 0.1874 - y1_output_root_mean_squared_error: 0.3028 - y2_output_root_mean_squared_error: 0.4330 - val_loss: 0.7864 - val_y1_output_loss: 0.2290 - val_y2_output_loss: 0.5560 - val_y1_output_root_mean_squared_error: 0.4799 - val_y2_output_root_mean_squared_error: 0.7457
# Epoch 496/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4384 - y1_output_loss: 0.1111 - y2_output_loss: 0.3234 - y1_output_root_mean_squared_error: 0.3345 - y2_output_root_mean_squared_error: 0.5714 - val_loss: 0.7301 - val_y1_output_loss: 0.2529 - val_y2_output_loss: 0.4799 - val_y1_output_root_mean_squared_error: 0.5057 - val_y2_output_root_mean_squared_error: 0.6888
# Epoch 497/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3207 - y1_output_loss: 0.0988 - y2_output_loss: 0.2229 - y1_output_root_mean_squared_error: 0.3137 - y2_output_root_mean_squared_error: 0.4715 - val_loss: 0.7929 - val_y1_output_loss: 0.2576 - val_y2_output_loss: 0.5367 - val_y1_output_root_mean_squared_error: 0.5116 - val_y2_output_root_mean_squared_error: 0.7288
# Epoch 498/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3078 - y1_output_loss: 0.0974 - y2_output_loss: 0.2087 - y1_output_root_mean_squared_error: 0.3134 - y2_output_root_mean_squared_error: 0.4578 - val_loss: 0.6466 - val_y1_output_loss: 0.1820 - val_y2_output_loss: 0.4622 - val_y1_output_root_mean_squared_error: 0.4318 - val_y2_output_root_mean_squared_error: 0.6784
# Epoch 499/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3700 - y1_output_loss: 0.1059 - y2_output_loss: 0.2642 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.5136 - val_loss: 0.7277 - val_y1_output_loss: 0.1943 - val_y2_output_loss: 0.5225 - val_y1_output_root_mean_squared_error: 0.4452 - val_y2_output_root_mean_squared_error: 0.7276
# Epoch 500/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3195 - y1_output_loss: 0.1002 - y2_output_loss: 0.2187 - y1_output_root_mean_squared_error: 0.3151 - y2_output_root_mean_squared_error: 0.4693 - val_loss: 0.6794 - val_y1_output_loss: 0.2457 - val_y2_output_loss: 0.4295 - val_y1_output_root_mean_squared_error: 0.5011 - val_y2_output_root_mean_squared_error: 0.6545

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 32us/sample - loss: 0.6794 - y1_output_loss: 0.2480 - y2_output_loss: 0.4250 - y1_output_root_mean_squared_error: 0.5011 - y2_output_root_mean_squared_error: 0.6545
# Loss = 0.6793767182857959, Y1_loss = 0.24796494841575623, Y1_mse = 0.5010698437690735, Y2_loss = 0.4249841272830963, Y2_mse = 0.6544506549835205

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
